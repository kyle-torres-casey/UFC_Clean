# %%
import pandas as pd
combined_df = pd.read_csv("combined_df_923.csv")

# %%
combined_df.head()
# Out:
#    Unnamed: 0                                 Event                 Date  \
# 0           0   UFC Fight Night: Dolidze vs. Imavov  2024-02-03 00:00:00
# 1           1  UFC Fight Night: Lemos vs. Jandiroba  2024-07-20 00:00:00
# 2           2         UFC on FOX: Johnson vs. Bader  2016-01-30 00:00:00
# 3           3         UFC on FOX: Teixeira vs Evans  2016-04-16 00:00:00
# 4           4  UFC Fight Night: Poirier vs. Johnson  2016-09-17 00:00:00
#
#                   Location W/L 1 W/L 2        Fighter 1       Fighter 2  Kd 1  \
# 0   Las Vegas, Nevada, USA   NaN   win  Thomas Petersen    Jamal Pogues     0
# 1   Las Vegas, Nevada, USA   win   NaN  Thomas Petersen  Mohammed Usman     0
# 2  Newark, New Jersey, USA   win   NaN      Randy Brown      Matt Dwyer     0
# 3      Tampa, Florida, USA   NaN   win      Randy Brown  Michael Graves     0
# 4      Hidalgo, Texas, USA   win   NaN      Randy Brown   Erick Montano     0
#
# ...

# %%
specific = combined_df[combined_df['Event'].str.contains('UFC 299', case=False, na=False)].copy()

# %%
specific
# Out:
#       Unnamed: 0                         Event                 Date  \
# 502          502  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 1043        1043  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 1075        1075  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 1231        1231  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 3603        3603  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 3804        3804  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 5633        5633  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 5647        5647  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 5903        5903  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 6363        6363  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 6577        6577  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 6903        6903  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 7054        7054  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# ...

# %%
#-----

# %%
ufc_combined = pd.read_csv("ufc_combined_0923_2.csv")

# %%
ufc_combined.head()
# Out:
#    Unnamed: 0  Winner                                 Event  \
# 0           0       1   UFC Fight Night: Dolidze vs. Imavov
# 1           1       1  UFC Fight Night: Lemos vs. Jandiroba
# 2           2       1         UFC on FOX: Johnson vs. Bader
# 3           3       1         UFC on FOX: Teixeira vs Evans
# 4           4       1  UFC Fight Night: Poirier vs. Johnson
#
#                   Date                 Location W/L 2        Fighter 1  \
# 0  2024-02-03 00:00:00   Las Vegas, Nevada, USA   win     Jamal Pogues
# 1  2024-07-20 00:00:00   Las Vegas, Nevada, USA   NaN  Thomas Petersen
# 2  2016-01-30 00:00:00  Newark, New Jersey, USA   NaN      Randy Brown
# 3  2016-04-16 00:00:00      Tampa, Florida, USA   win   Michael Graves
# 4  2016-09-17 00:00:00      Hidalgo, Texas, USA   NaN      Randy Brown
#
#          Fighter 2  Kd 1  Kd 2  ...  Streak 2  Career W 2 Career L 2  \
# 0  Thomas Petersen     0     0  ...       0.0          -1         -1
# ...

# %%
odds = combined_df[combined_df['Event'].str.contains('UFC 299', case=False, na=False)].copy()

# %%
odds
# Out:
#       Unnamed: 0                         Event                 Date  \
# 502          502  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 1043        1043  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 1075        1075  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 1231        1231  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 3603        3603  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 3804        3804  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 5633        5633  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 5647        5647  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 5903        5903  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 6363        6363  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 6577        6577  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 6903        6903  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# 7054        7054  UFC 299: O'Malley vs. Vera 2  2024-03-09 00:00:00
# ...

# %%
from Processing_and_Stats import clean_bouts_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 4
#       1 import sys
#       2 sys.path.append('/Scripts')
# ----> 4 from Processing_and_Stats import clean_bouts_data
#
# ModuleNotFoundError: No module named 'Processing_and_Stats'
